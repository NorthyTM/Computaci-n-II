# %%
import pandas as pd
import numpy as np

analisis = pd.read_csv("videojuegos_nan_duplicates.csv")
pd.set_option('display.max_rows', None)

analisis

#Descripción del contenido

print(analisis.describe())
print(analisis.tail())

#Mostrar Información

print(analisis.head())
print(analisis.info())

#Análisis/limpieza de datos

analisis = pd.DataFrame(analisis)
print(analisis.isnull())
print(analisis.isnull().sum())

analisisisna = pd.DataFrame(analisis).isna()
print(analisis)

analisisnotnull = pd.DataFrame(analisis).notnull()
print(analisis)

analisisfillna = pd.DataFrame(analisis).fillna(10)
print(analisis)


#Eliminación de duplicados

analisisdropna = pd.DataFrame(analisis).dropna(axis = 0)
print(analisis)

analisisdrop = pd. DataFrame(analisis).drop_duplicates()
print(analisis)

#Filtrado de datos

print(analisis.loc[0])
print(analisis.iloc[0:5, 0:3])

print(analisis.loc[lo])
print(analisis.loc[:,["id", "title", "genre", "platform", "release_year", "decade", "rating", "sales_millions", "genre_copy", "rating_copy"]])
print(analisis.loc[analisis["raiting"]>5])
# Out:
#                id  release_year      rating  sales_millions  rating_copy
# count  474.000000    464.000000  474.000000      477.000000   474.000000
# mean   246.493671   2000.247845    5.519409        9.716059     5.519409
# std    143.421277     11.833848    2.512994        5.765044     2.512994
# min      1.000000   1980.000000    1.100000        0.140000     1.100000
# 25%    122.250000   1990.000000    3.400000        4.840000     3.400000
# 50%    245.500000   2000.500000    5.500000        9.380000     5.500000
# 75%    367.750000   2011.000000    7.700000       14.830000     7.700000
# max    500.000000   2019.000000   10.000000       19.980000    10.000000
#         id     title    genre platform  release_year decade  rating  \
# 515  190.0  Game 370      RPG      NaN           NaN  2010s     NaN
# 516  435.0       NaN   Action      PS3        1998.0    80s     5.6
# 517  290.0  Game 715   Puzzle       PC           NaN  2010s     8.1
# ...
