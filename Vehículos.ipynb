# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# --- Dataframe de 700 registros ---

estadistica = pd.read_csv("vehiculos_700_registros.csv")
pd.set_option('display.max_rows', None)

# Mostrar el dataframe
estadistica

# --- Estadística descriptiva básica ---

print(estadistica.info())
print(estadistica.head())
print(estadistica.describe())
print(estadistica.shape)
print(estadistica.dtypes)

col_nombre = estadistica.iloc[:, 0]
col_precio = estadistica.iloc[:, 1]
col_ventas = estadistica.iloc[:, 2]

print(f"\nPromedio de ventas: {col_ventas.mean()}")
print(f"Valor mínimo de ventas: {col_ventas.min()}")
print(f"Valor máximo de ventas: {col_ventas.max()}")
print(f"Desviación estándar (Ventas): {col_ventas.std()}")
print(f"Desviación estándar (Precio): {col_precio.std()}")

# --- Gráfico de Barras (Precios de Vehículo) ---
plt.figure(figsize=(12, 6))
# Graficamos los primeros 10 registros
plt.bar(col_nombre.head(10), col_precio.head(10), color='royalblue')
plt.title("Precio de Vehículos (Top 10)")
plt.xlabel("Nombre del Vehículo")
plt.ylabel("Precio")
plt.xticks(rotation=45) 
plt.show()

# --- Histograma (Ventas de Vehículo) ---
plt.figure(figsize=(10, 5))
plt.hist(col_ventas, bins=20, color="skyblue", edgecolor="black")
plt.title("Distribución en Histograma de Ventas")
plt.xlabel("Rango de Ventas")
plt.ylabel("Frecuencia (Cantidad de Vehículos)")
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    700 non-null    int64
#  1   Nombre_Vehiculo       700 non-null    object
#  2   Precio                700 non-null    float64
#  3   Placas                700 non-null    object
#  4   Numericas             700 non-null    int64
#  5   Ventas_Vehiculo       700 non-null    int64
#  6   Vehiculos_Existencia  700 non-null    int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 38.4+ KB
# None
#    ID   Nombre_Vehiculo    Precio    Placas  Numericas  Ventas_Vehiculo  \
# 0   1    Toyota Corolla  38014.65  P2675XYZ     483638               19
# 1   2  Volkswagen Jetta  18587.56  P3159XYZ     107341               97
# 2   3     Nissan Sentra  44076.61  P7670XYZ     980839               10
# 3   4           Kia Rio  31379.37  P5685XYZ     674994               59
# 4   5       Honda Civic  15504.11  P5587XYZ     848673               79
#
#    Vehiculos_Existencia
# 0                    36
# 1                    14
# 2                    42
# 3                    21
# 4                    21
#               ID        Precio      Numericas  Ventas_Vehiculo  \
# count  700.00000    700.000000     700.000000       700.000000
# mean   350.50000  28479.619586  546443.918571        51.232857
# std    202.21688   9361.550858  267116.632496        29.447100
# min      1.00000  12045.750000  100894.000000         0.000000
# 25%    175.75000  20468.757500  308104.000000        25.000000
# 50%    350.50000  28835.365000  529247.500000        54.000000
# 75%    525.25000  36662.865000  789272.250000        77.000000
# max    700.00000  44847.430000  999612.000000       100.000000
#
#        Vehiculos_Existencia
# count            700.000000
# mean              26.087143
# std               14.705195
# min                0.000000
# 25%               14.000000
# 50%               27.000000
# 75%               39.000000
# max               50.000000
# (700, 7)
# ID                        int64
# Nombre_Vehiculo          object
# Precio                  float64
# Placas                   object
# Numericas                 int64
# Ventas_Vehiculo           int64
# Vehiculos_Existencia      int64
# dtype: object
#
# Promedio de ventas: 28479.61958571429
# Valor mínimo de ventas: 12045.75
# Valor máximo de ventas: 44847.43
# Desviación estándar (Ventas): 9361.5508584088
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\nanops.py:85, in disallow.__call__.<locals>._f(*args, **kwargs)
#      84 try:
# ---> 85     return f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\nanops.py:1013, in nanvar(values, axis, skipna, ddof, mask)
#    1007 # xref GH10242
#    1008 # Compute variance via two-pass algorithm, which is stable against
#    1009 # cancellation errors and relatively accurate for small numbers of
#    1010 # observations.
#    1011 #
#    1012 # See https://en.wikipedia.org/wiki/Algorithms_for_calculating_variance
# -> 1013 avg = _ensure_numeric(values.sum(axis=axis, dtype=np.float64)) / count
#    1014 if axis is not None:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\numpy\core\_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# ValueError: could not convert string to float: 'Toyota Corolla'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 33
#      31 print(f"Valor máximo de ventas: {col_ventas.max()}")
#      32 print(f"Desviación estándar (Ventas): {col_ventas.std()}")
# ---> 33 print(f"Desviación estándar (Precio): {col_precio.std()}")
#      35 # --- Gráfico de Barras (Precios de Vehículo) ---
#      36 plt.figure(figsize=(12, 6))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:6592, in Series.std(self, axis, skipna, ddof, numeric_only, **kwargs)
#    6583 @doc(make_doc("std", ndim=1))
#    6584 def std(
#    6585     self,
#    (...)
#    6590     **kwargs,
#    6591 ):
# -> 6592     return NDFrame.std(self, axis, skipna, ddof, numeric_only, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:12358, in NDFrame.std(self, axis, skipna, ddof, numeric_only, **kwargs)
#   12350 def std(
#   12351     self,
#   12352     axis: Axis | None = 0,
#    (...)
#   12356     **kwargs,
#   12357 ) -> Series | float:
# > 12358     return self._stat_function_ddof(
#   12359         "std", nanops.nanstd, axis, skipna, ddof, numeric_only, **kwargs
#   12360     )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:12322, in NDFrame._stat_function_ddof(self, name, func, axis, skipna, ddof, numeric_only, **kwargs)
#   12319 elif axis is lib.no_default:
#   12320     axis = 0
# > 12322 return self._reduce(
#   12323     func, name, axis=axis, numeric_only=numeric_only, skipna=skipna, ddof=ddof
#   12324 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6452     # GH#47500 - change to TypeError to match other methods
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\nanops.py:950, in nanstd(values, axis, skipna, ddof, mask)
#     947 orig_dtype = values.dtype
#     948 values, mask = _get_values(values, skipna, mask=mask)
# --> 950 result = np.sqrt(nanvar(values, axis=axis, skipna=skipna, ddof=ddof, mask=mask))
#     951 return _wrap_results(result, orig_dtype)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\nanops.py:92, in disallow.__call__.<locals>._f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#      91     if is_object_dtype(args[0]):
# ---> 92         raise TypeError(e) from e
#      93     raise
#
# TypeError: could not convert string to float: 'Toyota Corolla'
