# %%
import pandas as pd

hospital = pd.read_csv("hospital_datos_modificado.csv")
pd.set_option('display.max_rows', None)

hospital

hospital = pd.DataFrame(hospital)
print(hospital.isnull())
print(hospital.isnull().sum())

hospitalisna = pd.DataFrame(hospital).isna()
print(hospital)

hospitalnotnull = pd.DataFrame(hospital).notnull()
print(hospital)

hospitalfillna = pd.DataFrame(hospital).fillna(10)
print(hospital)

hospitaldropna = pd.DataFrame(hospital).dropna(axis = 0)
print(hospital)

hospitaldrop = pd. DataFrame(hospital).drop_duplicates()
print(hospital)
# Out:
#         ID   Edad  Genero  Diagnostico  Costo
# 0    False  False   False         True  False
# 1    False  False   False        False  False
# 2    False  False    True        False  False
# 3    False  False   False         True  False
# 4    False  False   False        False  False
# 5    False  False    True        False  False
# 6    False  False   False        False   True
# 7    False  False   False        False  False
# 8     True  False   False        False  False
# 9    False  False   False        False  False
# 10   False  False   False        False  False
# 11    True  False    True        False  False
# 12   False   True   False        False  False
# 13   False  False   False         True  False
# 14    True  False   False        False  False
# 15   False  False   False        False  False
# 16   False  False   False        False  False
# 17    True  False   False        False  False
# 18   False  False   False        False   True
# ...
